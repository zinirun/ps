# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(A,B):
    A.sort()
    B.sort(reverse=True)
    s=0
    while A:
        s+=(A.pop(0)*B.pop(0))
    return s

# %%
print(solution([1,4,2],[5,4,4]))
# Out:
# 29
