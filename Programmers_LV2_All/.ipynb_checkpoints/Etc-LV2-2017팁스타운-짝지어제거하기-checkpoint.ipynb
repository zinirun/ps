# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s): 
    stack = []
    for i in s:
        if len(stack) == 0: stack.append(i)
        elif stack[-1] == i: stack.pop()
        else: stack.append(i)
    return 0 if stack else 1

# %%
print(solution('caabbccaaddc'))
# Out:
# 1
