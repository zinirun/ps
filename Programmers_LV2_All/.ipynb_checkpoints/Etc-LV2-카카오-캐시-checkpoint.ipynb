# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - LRU 알고리즘: 가장 오래 사용되지 않은 페이지를 교체하는 알고리즘
# ![image.png](attachment:image.png)

# %%
def solution(cacheSize, cities):
    c = []
    t = 0
    if cacheSize==0: return 5*len(cities)
    for i in cities:
        if i.lower() in c:
            t += 1
            del c[c.index(i.lower())]
            c.append(i.lower())
        else:
            t += 5
            if len(c)+1>cacheSize:
                del c[0]
            c.append(i.lower())
        print(c)
    return t

# %%
print(solution(3,['LA', 'ABC', 'ABC', 'LA','LA','LA','KKK','LA','AAAAA']))
# Out:
# ['la']
# ['la', 'abc']
# ['la', 'abc']
# ['abc', 'la']
# ['abc', 'la']
# ['abc', 'la']
# ['abc', 'la', 'kkk']
# ['abc', 'kkk', 'la']
# ['kkk', 'la', 'aaaaa']
# 25
