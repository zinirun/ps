# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    s=n+1
    N=str(bin(n)[2:]).count('1')
    while True:
        if str(bin(s)[2:]).count('1')==N:
            return s
        s+=1
