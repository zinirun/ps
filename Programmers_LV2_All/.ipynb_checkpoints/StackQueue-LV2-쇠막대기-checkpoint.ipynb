# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(arrangement):
    a = arrangement.replace('()','R')
    s = []
    cut = 0
    for i, c in enumerate(a):
        if c == '(': s.append(i)
        if c == ')': cut += (a[s.pop():i].count('R')+1)
    return cut
