# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
def solution(w,h):
    return w*h - (w+h-math.gcd(w,h))

# %%
print(solution(2, 3))
# Out:
# 2
