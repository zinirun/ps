# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import permutation
def solution(baseball):
    candidate = []
    for i in baseball:
