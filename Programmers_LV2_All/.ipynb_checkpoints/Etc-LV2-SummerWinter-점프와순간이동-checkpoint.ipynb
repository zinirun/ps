# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    c=1
    while n>1:
        n,e=n//2,n%2
        if e==0:
            continue
        else:
            c+=1
    return c

# %%
print(solution(5))
# Out:
# 2
