# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s):
    return ' '.join([i[0].upper()+i[1:] if i[0].isalpha() else i for i in s.lower().split()])

# %%
print(solution('3people unFollowed mE'))
# Out:
# 3

# %% [markdown]
# -> 공백도 그대로 반환해야해서 split을 사실상 사용불가
