# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    m=1
    for i in range(1, n//2+1):
        t=i
        for j in range(i+1, n//2+2):
            t+=j
            if t==n:
                m+=1
                break
            if t>n:
                break
    return m

# %%
print(solution(15))
# Out:
# 4
