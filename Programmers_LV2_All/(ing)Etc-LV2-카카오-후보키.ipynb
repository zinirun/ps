# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from itertools import combinations
def solution(relation):
    r=0
    s=np.transpose(relation)
    print(s)
    c=[]
    for i in range(1,len(s)+1):
        c.append(list(map(list,(combinations(range(0,len(relation[0])),i)))))
    for i in c:
        for j in i:
            t=[]
            t_=[]*len(j)
            for k in j:
                for m in c:
                    print(m)
                    t_[m]+=c[m]
            print(t_)
    
    return r

# %%
print(solution([["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]))
# Out:
# [['100' '200' '300' '400' '500' '600']
#  ['ryan' 'apeach' 'tube' 'con' 'muzi' 'apeach']
#  ['music' 'math' 'computer' 'computer' 'music' 'music']
#  ['2' '2' '3' '4' '3' '2']]
# 0
# ----------------------------------------------------------------------
# IndexError                           Traceback (most recent call last)
# <ipython-input-91-bd9615414928> in <module>
# ----> 1 print(solution([["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]))
#
# <ipython-input-90-364bea184e58> in solution(relation)
#      15                 for m in range(k+1):
#      16                     print(m)
# ---> 17                     t_[m]+=c[m]
#      18             print(t_)
#      19
#
# IndexError: list index out of range

# %%
import numpy as np
from itertools import combinations
def solution(relation):
    r=0
    s=np.transpose(relation)
    print(s)
    c=[]
    for i in range(1,len(s)+1):
        c.append(list(map(list,(combinations(,i)))))
    print(c)
    
    return r

# %%
print(solution([["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]))
# Out:
# [['100' '200' '300' '400' '500' '600']
#  ['ryan' 'apeach' 'tube' 'con' 'muzi' 'apeach']
#  ['music' 'math' 'computer' 'computer' 'music' 'music']
#  ['2' '2' '3' '4' '3' '2']]
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-83-bd9615414928> in <module>
# ----> 1 print(solution([["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]))
#
# <ipython-input-82-f77bb99cd81b> in solution(relation)
#       7     c=[]
#       8     for i in range(1,len(s)+1):
# ----> 9         c.append(list(map(list,(combinations(list(''.join([s[i]])),i)))))
#      10     print(c)
#      11
#
# TypeError: sequence item 0: expected str instance, numpy.ndarray found
