# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(brown, yellow):
    y_=[]
    for i in range(1, int(yellow**0.5)+1):
        if yellow%i==0: y_.append([yellow//i, i])
    for i in y_:
        if i[0]*2 + i[1]*2 + 4 == brown:
            return [i[0]+2, i[1]+2]

# %%
print(solution(24, 24))
# Out:
# [[24, 1], [12, 2], [8, 3], [6, 4]]
# [8, 6]
