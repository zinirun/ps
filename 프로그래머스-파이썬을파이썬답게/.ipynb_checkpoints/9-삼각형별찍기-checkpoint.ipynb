# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input().strip())
for i in range(n):
    print('*'*(i+1))
# Out:
# 3
# *
# **
# ***

# %% [markdown]
# ### * 응용

# %%
answer = [123, 456] * 3
print(answer)
# Out:
# [123, 456, 123, 456, 123, 456]
