# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 1
for i in range(5):
    a = a * int(input())
    if(a ** 0.5 % 1 == 0):
        print('found')
        break
else:
    print('not found')
# Out:
# 5
# 1
# 2
# 3
# 1
# not found
