# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a, b = map(int, input().strip().split(' '))
print(a//b, a%b)
# Out:
# 5 3
# 1 2

# %% [markdown]
# ### 파이썬다운 답

# %%
a, b = map(int, input().strip().split(' '))
print(*divmod(a,b))
# Out:
# 5 3
# 1 2
