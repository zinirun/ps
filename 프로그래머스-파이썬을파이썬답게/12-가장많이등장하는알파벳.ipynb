# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from collections import Counter
my_str = sorted(input().strip())
cnt = Counter(my_str)
m = max(cnt.values())
cnt = cnt.most_common()
answer = [i[0] for i in cnt if i[1] is m]
print(''.join(answer))
# Out:
# dfdefdgf
# df
