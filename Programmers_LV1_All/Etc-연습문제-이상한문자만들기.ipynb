# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s):
    a = ''
    cnt = 0
    for i, c in enumerate(s):
        if c != ' ':
            cnt += 1
            if cnt%2==0: a+=c.lower()
            else: a+=c.upper()
        else:
            cnt = 0
            a+=' '
    return a
