# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s, n):
    b = ''
    t = 0
    for i in s:
        t = ord(i)
        if 65<=t<=90 or 97<=t<=122: t+=n%26
        b += chr(t)
    return b

print(solution('ab AZz', 1))
# Out:
# bc B[{
