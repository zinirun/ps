# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    a = []
    for i in range(1, int(n**0.5)+1):
        if n % i == 0:
            a.append(i)
            a.append(n//i)
    return sum(set(a))
