# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(arr):
    answer = []
    for i in arr:
        if len(answer) > 0 and i == answer[len(answer)-1]: continue
        answer.append(i)
    return answer

print(solution([1,1,3,3,0,1,1]))
# Out:
# [1, 3, 0, 1]
