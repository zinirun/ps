# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(clothes):
    s = dict(clothes)
    for item, category in enumerate(s):
        

print(solution([['yellow_hat', 'headgear'], ['blue_sunglasses', 'eyewear'], ['green_turban', 'headgear']]))
# Out:
# headgear
# eyewear
# headgear
# None
