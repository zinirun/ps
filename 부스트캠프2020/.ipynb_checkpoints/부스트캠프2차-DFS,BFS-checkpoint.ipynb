# %% [markdown]
# ![image.png](attachment:image.png)

# %%
node = {'A':{'B':1,'C':2,'F':4},
        'B':{'E':1,'D':2},
        'C':{'D':2},
        'D':{'K':2,'G':1},
        'E':{'H':1},
        'F':{'G':3},
        'G':{'H':1,'J':3,'I':2},
        'H':{'K':2,'J':1},
        'I':{'J':2}}

# %%
start,end=map(input().split())
s=end
n=[]
while 1:
